# %%
number_of_classes = int(input("How many classes do you take:"))
# numbers0 = [int(word) for word in number_of_classes.split() if word.isdigit()]

Honors_Classes = int(input("How many honors classes do you take: "))

Ap_Classes = int(input("How many AP classes do you take: "))

Math_grade_name = int(input("Math Grade: "))
# numbers1 = [int(word) for word in Math_grade_name.split() if word.isdigit()]


Science_grade = int(input("Science Grade: "))
# numbers2 = [int(word) for word in Science_grade.split() if word.isdigit()]

Language_arts_grade = int(input("Language Arts Grade: "))
# numbers3 = [int(word) for word in Language_arts_grade.split() if word.isdigit()]

History_grade = int(input("History Grade: "))
# numbers4 = [int(word) for word in History_grade.split() if word.isdigit()]

PhysEd_grade = int(input("Physical Educaition Grade: "))
# numbers5 = [int(word) for word in PhysEd_grade.split() if word.isdigit()]

Second_language_grade = int(input("Second Language Grade: "))
# numbers6 = [int(word) for word in Second_language_grade.split() if word.isdigit()]

Elective1_grade = int(input("Elective 1 Grade: "))
# numbers7 = [int(word) for word in Elective1_grade.split() if word.isdigit()]

Elective2_grade = int(input("Elective 2 Grade: "))
# numbers8 = [int(word) for word in Elective2_grade.split() if word.isdigit()]

Final_grade_Sum = Math_grade_name + Science_grade + Language_arts_grade + History_grade + PhysEd_grade + Second_language_grade + Elective1_grade + Elective2_grade;
Weighted_AP_Classes = Ap_Classes * 10;
Weighted_Honors_Classes = Honors_Classes * 8;
Weighted_Final_grade_sum = Final_grade_Sum + Weighted_AP_Classes + Weighted_Honors_Classes;
Final_grade_sum2 = Weighted_Final_grade_sum/number_of_classes;
Final_grade_average = Final_grade_Sum/number_of_classes;
UnweightedGPA1 = Final_grade_average/100;
UnweightedGPA_Final = (UnweightedGPA1 * 4) + 0.10;
WeightedGPA = ((Final_grade_sum2/110) * 5);

print("Unweighted GPA: " + str(UnweightedGPA_Final))
print("Weighted GPA:" + str(WeightedGPA))
# Out:
# How many classes do you take:8
# How many honors classes do you take: 3
# How many AP classes do you take: 1
# Math Grade: 93
# Science Grade: 87
# Language Arts Grade: 81
# History Grade: 86
# Physical Educaition Grade: 100
# Second Language Grade: 80
# Elective 1 Grade: 100
# Elective 2 Grade: 90
# Unweighted GPA: 3.685
# Weighted GPA:4.267045454545454
